'138', '8373', '1424', '5215', '1418', '7830', '1231', '207', '573', '572', '118', '900', '13', '8518', '1109', '7710', '5120', '549', '45', '4', '1009', '2323', '1315', '8593', '8597', '256', '7579', '2179', '260', '43', '1055', '9358', '1019', '2318', '8598', '6668', '1022', '1053', '1047', '2186', '2397', '1454', '1301', '4461', '115', '1051', '2581', '1056', '2026', '2578', '77', '2184', '6999', '1041', '5083', '2183', '7694', '325', '7727', '520', '2099', '64', '140', '2181', '1002', '1036', '52', '12', '2580', '1039', '1461', '7535', '108', '7776', '17', '1125', '2312', '7513', '1000', '1429', '44', '7512', '1', '1027', '76', '7802', '2041', '1003', '1017', '1460', '1029', '5077', '63', '1004', '6393', '327', '5206', '7672', '2040', '61', '24', '116', '7582', '23', '4462', '20', '125', '1437', '2037', '2176', '1462', '7578', '2178', '303', '5666', '57']
degree = ['1315', '7513', '2040', '44', '1429', '1437', '7535', '1462', '2037', '2178', '2041', '7582', '7512', '20', '125', '116', '57', '5666', '6393']

# %%
len(graph), len(nbr), len(degree)
# Out:
# (116, 482, 19)

# %%
list(set(degree) & set(graph) & set(nbr))
# Out:
# ['5666',
#  '125',
#  '7513',
#  '20',
#  '57',
#  '7582',
#  '44',
#  '116',
#  '2040',
#  '2037',
#  '2041',
#  '1429',
#  '6393',
#  '1437',
#  '7512',
#  '1315',
#  '2178',
#  '7535',
#  '1462']

# %%
for v in degree:
    assert v in nbr
    assert v in graph

# %%
import pandas as pd
df = pd.read_csv("../data/kdcore_enron.csv", header=None)
df.columns = ['vertex', 'k', 'd']
df
# Out:
#       vertex   k  d
# 0        149  24  3
# 1          3  23  4
# 2        150   4  1
# 3        151  11  3
# 4         64  24  5
# ...      ...  .. ..
# 4418    8699  24  1
# 4419   12719   1  1
# 4420   12678   1  1
# 4421   12721   2  1
# 4422   12722   1  1
#
# [4423 rows x 3 columns]

# %%
df.sort_values(by=['k', 'd'], ascending=False, inplace=True)
df
# Out:
#       vertex   k   d
# 16       116  24  11
# 250     1429  24  11
# 251     1437  24  11
# 473      125  24  11
# 475     1315  24  11
# ...      ...  ..  ..
# 4403   12659   1   1
# 4404   12660   1   1
# 4419   12719   1   1
# 4420   12678   1   1
# 4422   12722   1   1
#
# [4423 rows x 3 columns]

# %%
kd = {}
group_list = ['k', 'd']
for key, item in df.groupby(group_list, as_index=False):
    # print(item[''])
    assert len(item['vertex'].unique()) == item.shape[0]
    kd[key] = list(item['vertex'].unique())

# %%
kd
# Out:
# {(1, 1): [153,
#   157,
#   158,
#   258,
#   259,
#   270,
#   273,
#   274,
#   283,
#   288,
#   289,
#   290,
#   291,
#   292,
#   296,
#   298,
#   301,
#   335,
#   336,
#   558,
#   561,
#   562,
#   565,
#   1306,
#   1353,
#   1360,
#   1364,
#   1365,
#   1395,
#   1396,
#   1401,
#   1402,
#   1403,
#   1404,
#   1409,
#   1410,
#   1411,
#   1412,
#   1413,
#   1417,
#   1419,
#   1420,
#   1464,
#   1611,
#   1612,
#   1631,
#   1664,
#   1676,
#   1677,
#   1678,
#   1679,
#   1685,
#   1686,
#   1689,
#   1690,
#   1691,
#   1692,
#   1694,
#   1695,
#   1696,
#   1697,
#   1698,
#   1699,
#   1701,
#   1702,
#   1703,
#   1704,
#   1780,
#   1798,
#   1799,
#   1805,
#   1809,
#   1850,
#   1808,
#   1853,
#   1912,
#   1913,
#   1961,
#   1877,
#   1969,
#   1970,
#   1977,
#   1978,
#   2002,
#   2008,
#   1962,
#   2033,
#   2050,
#   2068,
#   2069,
#   2071,
#   2084,
#   2085,
#   2086,
#   608,
#   919,
#   2536,
#   2549,
#   2576,
#   2590,
#   960,
# ...
